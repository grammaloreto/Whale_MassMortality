# %%
#Dependencies
import pandas as pd
from fbprophet import Prophet
import matplotlib.pyplot as plt

# %% [markdown]
# **Monthly Chlorophyll concentration 2000-2022 in lon, lat = -75.5 , -45. Golfo de Penas. Chilean Patagonia**

# %%
df = pd.read_csv('data/prophet_chl_monthly_2000-2022_whales.csv')

# %%
df
# Out:
#              ds         y
# 0    2000-01-01  0.714228
# 1    2000-02-01  0.745135
# 2    2000-03-01  0.700188
# 3    2000-04-01  0.460281
# 4    2000-05-01  1.032823
# ..          ...       ...
# 260  2021-09-01  0.824019
# 261  2021-10-01  0.771279
# 262  2021-11-01  1.474253
# 263  2021-12-01  1.021748
# 264  2022-01-01  1.066612
#
# [265 rows x 2 columns]

# %%
# Enabling yearly seasonality
# Train model
m = Prophet(interval_width=0.95, yearly_seasonality=True) # confidence interval of 95%
model = m.fit(df) # fit method
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\smart\Anaconda3\envs\mlpycaret\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
# Forecast
future = m.make_future_dataframe(periods=100,freq='D')
forecast = m.predict(future)
forecast.head()
# Out:
# C:\Users\smart\Anaconda3\envs\mlpycaret\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\smart\Anaconda3\envs\mlpycaret\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2000-01-01  0.729802    0.243703    1.499987     0.729802     0.729802
# 1 2000-02-01  0.730468    0.346240    1.558168     0.730468     0.730468
# 2 2000-03-01  0.731091    0.165995    1.453863     0.731091     0.731091
# 3 2000-04-01  0.731757    0.011299    1.275970     0.731757     0.731757
# 4 2000-05-01  0.732401   -0.213072    1.140698     0.732401     0.732401
#
# ...

# %%
forecast.tail(50)
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 315 2022-02-21  0.903453    0.615532    1.907042     0.903453     0.903453
# 316 2022-02-22  0.903474    0.568594    1.878307     0.903474     0.903474
# 317 2022-02-23  0.903496    0.595067    1.801625     0.903496     0.903496
# 318 2022-02-24  0.903517    0.498368    1.835171     0.903517     0.903517
# 319 2022-02-25  0.903539    0.484654    1.794168     0.903539     0.903539
# 320 2022-02-26  0.903560    0.468916    1.735871     0.903560     0.903560
# 321 2022-02-27  0.903582    0.419571    1.670742     0.903581     0.903582
# 322 2022-02-28  0.903603    0.381002    1.653968     0.903603     0.903603
# 323 2022-03-01  0.903624    0.334692    1.636180     0.903624     0.903624
# 324 2022-03-02  0.903646    0.345666    1.583558     0.903646     0.903646
# 325 2022-03-03  0.903667    0.267113    1.533717     0.903667     0.903667
# ...

# %%
plot1 = m.plot(forecast)
plt.savefig('images/TimeSeries-chl_yearly-2000-2022.png', dpi=100)

# %%
plt2 = m.plot_components(forecast)
plt.savefig('images/yearly-components_2000-2022.png', dpi=100)
# Out:
# C:\Users\smart\Anaconda3\envs\mlpycaret\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
