# %%
# # Dependencies
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as mpatches
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import warnings
warnings.filterwarnings('ignore')

# %%
# Paths to load the files

# Model temperature dataset
path_mod = 'data/cmems_mod_glo_phy_my_0.083_P1M-m_1662838544420.nc'

# # Products variables
mod = xr.open_dataset(path_mod)

# %%
mod
# Out:
# <xarray.Dataset>
# Dimensions:    (depth: 36, latitude: 61, time: 24, longitude: 85)
# Coordinates:
#   * depth      (depth) float32 0.494 1.541 2.646 3.819 ... 763.3 902.3 1.062e+03
#   * latitude   (latitude) float32 -49.0 -48.92 -48.83 ... -44.17 -44.08 -44.0
#   * time       (time) datetime64[ns] 2015-01-16T12:00:00 ... 2016-12-16T12:00:00
#   * longitude  (longitude) float32 -79.0 -78.92 -78.83 ... -72.17 -72.08 -72.0
# Data variables:
#     thetao     (time, depth, latitude, longitude) float32 ...
# Attributes: (12/17)
#     title:                         Monthly mean fields for product GLOBAL_REA...
#     references:                    http://marine.copernicus.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     licence:                       http://marine.copernicus.eu/services-portf...
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     producer:                      CMEMS - Global Monitoring and Forecasting ...
#     ...                            ...
#     source:                        MERCATOR GLORYS12V1
#     product_user_manual:           http://marine.copernicus.eu/documents/PUM/...
#     quality_information_document:  http://marine.copernicus.eu/documents/QUID...
#     _CoordSysBuilder:              ucar.nc2.dataset.conv.CF1Convention
#     comment:
#     history:                       Data extracted from dataset http://localho...

# %%
# Target Variable. Thetao or sea water potential temperature
temp_mod = mod['thetao']

temp_mod
# Out:
# <xarray.DataArray 'thetao' (time: 24, depth: 36, latitude: 61, longitude: 85)>
# [4479840 values with dtype=float32]
# Coordinates:
#   * depth      (depth) float32 0.494 1.541 2.646 3.819 ... 763.3 902.3 1.062e+03
#   * latitude   (latitude) float32 -49.0 -48.92 -48.83 ... -44.17 -44.08 -44.0
#   * time       (time) datetime64[ns] 2015-01-16T12:00:00 ... 2016-12-16T12:00:00
#   * longitude  (longitude) float32 -79.0 -78.92 -78.83 ... -72.17 -72.08 -72.0
# Attributes:
#     long_name:      Temperature
#     standard_name:  sea_water_potential_temperature
#     units:          degrees_C
#     unit_long:      Degrees Celsius
#     cell_methods:   area: mean
#     _ChunkSizes:    [  1   7 341 720]

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2015-01-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature January 2015',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_15-1.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2016-01-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature January 2016',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_16-1.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2015-02-15').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature February 2015',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_15-2.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2016-02-15').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature February 2016',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_16-2.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2015-03-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature March 2015',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_15-3.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2016-03-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature March 2016',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_16-3.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2015-04-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature April 2015',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_15-4.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2016-04-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature April 2016',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_16-4.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2015-05-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature May 2015',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_15-5.png')

# %%
# Select the temperature parameter, at the date and depth we want, and store it in a variable.
temp_mod = mod['thetao'].sel(depth=0,method='nearest').sel(time='2016-05-16').squeeze()

# Define the caracteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                            # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
im = ax.pcolor(temp_mod['longitude'].data, temp_mod['latitude'].data,temp_mod,vmin=8,vmax=16,cmap='plasma')
    

# Add the titles and legend
f.suptitle('Sea Surface Temperature May 2016',fontsize=25)                 # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.set_label('°C', rotation=270,fontsize=20)                                     # add the title of the colorbar

# Save figure
plt.savefig('images/temp/sst_penas_16-5.png')

# %% [markdown]
# # Time Series

# %%
# satellite observation dataset
path_sat = 'data/METOFFICE-GLO-SST-L4-NRT-OBS-SST-MON-V2_1662839440730.nc'

# # Product Variable
sat = xr.open_dataset(path_sat)

# %%
sat
# Out:
# <xarray.Dataset>
# Dimensions:       (lon: 29, time: 24, lat: 21)
# Coordinates:
#   * lon           (lon) float32 280.9 281.1 281.4 281.6 ... 287.4 287.6 287.9
#   * time          (time) datetime64[ns] 2015-01-15T12:00:00 ... 2016-12-15T12...
#   * lat           (lat) float32 -48.88 -48.62 -48.38 ... -44.38 -44.12 -43.88
# Data variables:
#     analysed_sst  (time, lat, lon) float32 283.6 283.6 283.6 ... nan nan nan
# Attributes: (12/48)
#     summary:                                        A merged, multi-sensor L4...
#     history:                                        Created from sst:temperat...
#     uuid:                                           5c1665b7-06e8-499d-a281-8...
#     metadata_link:                                  http://data.nodc.noaa.gov...
#     FROM_ORIGINAL_FILE__southernmost_latitude:      -90.0
#     FROM_ORIGINAL_FILE__northernmost_latitude:      90.0
#     ...                                             ...
#     sensor:                                         AVHRR, AVHRR_GAC, AVHRR_L...
#     FROM_ORIGINAL_FILE__westernmost_longitude:      0.0
#     FROM_ORIGINAL_FILE__easternmost_longitude:      360.0
#     acknowledgment:                                 Please acknowledge the us...
#     FROM_ORIGINAL_FILE__Metadata_Conventions:       Unidata Observation Datas...
#     _CoordSysBuilder:                               ucar.nc2.dataset.conv.CF1...

# %%
# Kelvin transformation

# Converting into Celcius degrees 
sat['analysed_sst']-273.16
# Out:
# <xarray.DataArray 'analysed_sst' (time: 24, lat: 21, lon: 29)>
# array([[[10.449982 , 10.459991 , 10.459991 , ...,  8.       ,
#           8.429993 ,        nan],
#         [10.569977 , 10.569977 , 10.569977 , ...,  7.720001 ,
#                 nan,        nan],
#         [10.649994 , 10.629974 , 10.639984 , ...,  7.6600037,
#                 nan,        nan],
#         ...,
#         [13.329987 , 13.349976 , 13.369995 , ..., 13.879974 ,
#                 nan,        nan],
#         [13.48999  , 13.509979 , 13.519989 , ...,        nan,
#                 nan,        nan],
#         [13.639984 , 13.660004 , 13.660004 , ...,        nan,
#                 nan,        nan]],
#
#        [[11.179993 , 11.089996 , 11.019989 , ...,  9.22998  ,
#           9.73999  ,        nan],
#         [11.279999 , 11.220001 , 11.209991 , ...,  8.849976 ,
#                 nan,        nan],
#         [11.379974 , 11.349976 , 11.399994 , ...,  8.75     ,
#                 nan,        nan],
# ...
#         [11.269989 , 11.279999 , 11.289978 , ..., 12.359985 ,
#                 nan,        nan],
#         [11.440002 , 11.440002 , 11.440002 , ...,        nan,
#                 nan,        nan],
#         [11.589996 , 11.589996 , 11.589996 , ...,        nan,
#                 nan,        nan]],
#
#        [[10.199982 , 10.149994 , 10.089996 , ...,  8.669983 ,
#           9.049988 ,        nan],
#         [10.309998 , 10.269989 , 10.220001 , ...,  8.25     ,
#                 nan,        nan],
#         [10.349976 , 10.329987 , 10.309998 , ...,  8.109985 ,
#                 nan,        nan],
#         ...,
#         [12.209991 , 12.22998  , 12.269989 , ..., 13.959991 ,
#                 nan,        nan],
#         [12.429993 , 12.449982 , 12.47998  , ...,        nan,
#                 nan,        nan],
#         [12.629974 , 12.660004 , 12.669983 , ...,        nan,
#                 nan,        nan]]], dtype=float32)
# Coordinates:
#   * lon      (lon) float32 280.9 281.1 281.4 281.6 ... 287.1 287.4 287.6 287.9
#   * time     (time) datetime64[ns] 2015-01-15T12:00:00 ... 2016-12-15T12:00:00
#   * lat      (lat) float32 -48.88 -48.62 -48.38 -48.12 ... -44.38 -44.12 -43.88

# %% [markdown]
# ### Cordinate #1

# %%
# Define the coordinates of the point on which to plot the time series
lon, lat = -75.5, -45.5
date_min, date_max = '2015-01-15', '2015-12-15'

# Select the temperature variable from the product, at this point and these dates
temp_sat = sat['analysed_sst'].sel(lon=lon,lat=lat,method='nearest').sel(time=slice(date_min,date_max))

# Convert Kelvin into Celsius
temp_sat = temp_sat - 273.15

# Display the content of the new variable
temp_sat
# Out:
# <xarray.DataArray 'analysed_sst' (time: 12)>
# array([12.600006, 13.769989, 13.649994, 12.959991, 11.899994, 10.540009,
#         9.579987,  9.040009,  8.799988,  9.      , 10.079987, 11.279999],
#       dtype=float32)
# Coordinates:
#     lon      float32 280.9
#   * time     (time) datetime64[ns] 2015-01-15T12:00:00 ... 2015-12-15T12:00:00
#     lat      float32 -45.38

# %%
# Define the caracteristics of the plot
f = plt.figure(figsize=(12,8))                                       # create a figure and define its size
ax = f.add_subplot(111)                                              # create the axes of the plot
ax.grid()                                                            # add the grid lines
ax.set_title("Sea Surface Temperature (°C)",fontsize=24)             # add the figure title
f.suptitle('Longitude : ' +str(lon) +'°E\nLatitude : ' + str(lat)+'°N',
           fontsize=18,horizontalalignment='left',x=0.12)            # Display the coordinates on the plot
f.autofmt_xdate()                                                    # format the dates in the x axis 
im = ax.plot(temp_sat['time'],temp_sat)                              # plot the time serie

# Display the location of the point on a mini map
ax_mini_map = f.add_axes([0.73, 0.91, 0.2, 0.15], projection=ccrs.PlateCarree())  # create the minimap and define its projection
gl = ax_mini_map.gridlines(draw_labels=True)                                      # add the coastlines
gl.right_labels = False                                                           # remove latitude labels on the right
gl.top_labels = False                                                             # remove longitude labels on the top
ax_mini_map.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                   # add land mask 
ax_mini_map.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                  # define the extent of the map [lon_min,lon_max,lat_min,lat_max]
ax_mini_map.scatter(lon, lat, 30,transform=ccrs.PlateCarree())                    # plot the location of the point

# Save figure
plt.savefig('images/temp/time_series_sst_penas_2015.png')

# %%
# Define the coordinates of the point on which to plot the time series
lon, lat = -75.5, -45.5
date_min, date_max = '2016-01-15', '2016-12-15'

# Select the temperature variable from the product, at this point and these dates
temp_sat = sat['analysed_sst'].sel(lon=lon,lat=lat,method='nearest').sel(time=slice(date_min,date_max))

# Convert Kelvin into Celsius
temp_sat = temp_sat - 273.15

# Display the content of the new variable
temp_sat
# Out:
# <xarray.DataArray 'analysed_sst' (time: 12)>
# array([13.290009, 14.290009, 14.23999 , 12.950012, 12.440002, 11.359985,
#        10.540009, 10.      ,  9.679993, 10.019989, 10.76001 , 11.769989],
#       dtype=float32)
# Coordinates:
#     lon      float32 280.9
#   * time     (time) datetime64[ns] 2016-01-15T12:00:00 ... 2016-12-15T12:00:00
#     lat      float32 -45.38

# %%
# Define the caracteristics of the plot
f = plt.figure(figsize=(12,8))                                       # create a figure and define its size
ax = f.add_subplot(111)                                              # create the axes of the plot
ax.grid()                                                            # add the grid lines
ax.set_title("Sea Surface Temperature (°C) 2016",fontsize=24)             # add the figure title
f.suptitle('Longitude : ' +str(lon) +'°E\nLatitude : ' + str(lat)+'°N',
           fontsize=18,horizontalalignment='left',x=0.12)            # Display the coordinates on the plot
f.autofmt_xdate()                                                    # format the dates in the x axis 
im = ax.plot(temp_sat['time'],temp_sat)                              # plot the time serie

# Display the location of the point on a mini map
ax_mini_map = f.add_axes([0.73, 0.91, 0.2, 0.15], projection=ccrs.PlateCarree())  # create the minimap and define its projection
gl = ax_mini_map.gridlines(draw_labels=True)                                      # add the coastlines
gl.right_labels = False                                                           # remove latitude labels on the right
gl.top_labels = False                                                             # remove longitude labels on the top
ax_mini_map.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                   # add land mask 
ax_mini_map.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                  # define the extent of the map [lon_min,lon_max,lat_min,lat_max]
ax_mini_map.scatter(lon, lat, 30,transform=ccrs.PlateCarree())                    # plot the location of the point

# Save figure
plt.savefig('images/temp/time_series_sst_penas_2016-1.png')

# %% [markdown]
# ### Coordinate #2

# %%
# Define the coordinates of the point on which to plot the time series
lon, lat = -75.8, -47.9
date_min, date_max = '2015-01-15', '2015-12-15'

# Select the temperature variable from the product, at this point and these dates
temp_sat = sat['analysed_sst'].sel(lon=lon,lat=lat,method='nearest').sel(time=slice(date_min,date_max))

# Convert Kelvin into Celsius
temp_sat = temp_sat - 273.15

# Display the content of the new variable
temp_sat
# Out:
# <xarray.DataArray 'analysed_sst' (time: 12)>
# array([10.899994 , 11.690002 , 11.5      , 10.720001 ,  9.899994 ,
#         8.720001 ,  8.139984 ,  7.600006 ,  7.619995 ,  7.9599915,
#         9.079987 , 10.029999 ], dtype=float32)
# Coordinates:
#     lon      float32 280.9
#   * time     (time) datetime64[ns] 2015-01-15T12:00:00 ... 2015-12-15T12:00:00
#     lat      float32 -47.88

# %%
# Define the caracteristics of the plot
f = plt.figure(figsize=(12,8))                                       # create a figure and define its size
ax = f.add_subplot(111)                                              # create the axes of the plot
ax.grid()                                                            # add the grid lines
ax.set_title("Sea Surface Temperature (°C)",fontsize=24)             # add the figure title
f.suptitle('Longitude : ' +str(lon) +'°E\nLatitude : ' + str(lat)+'°N',
           fontsize=18,horizontalalignment='left',x=0.12)            # Display the coordinates on the plot
f.autofmt_xdate()                                                    # format the dates in the x axis 
im = ax.plot(temp_sat['time'],temp_sat)                              # plot the time serie

# Display the location of the point on a mini map
ax_mini_map = f.add_axes([0.73, 0.91, 0.2, 0.15], projection=ccrs.PlateCarree())  # create the minimap and define its projection
gl = ax_mini_map.gridlines(draw_labels=True)                                      # add the coastlines
gl.right_labels = False                                                           # remove latitude labels on the right
gl.top_labels = False                                                             # remove longitude labels on the top
ax_mini_map.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                   # add land mask 
ax_mini_map.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                  # define the extent of the map [lon_min,lon_max,lat_min,lat_max]
ax_mini_map.scatter(lon, lat, 30,transform=ccrs.PlateCarree())                    # plot the location of the point

# Save figure
plt.savefig('images/temp/time_series_sst_penas_2015-2.png')

# %%
# Define the coordinates of the point on which to plot the time series
lon, lat = -75.8, -47.9
date_min, date_max = '2016-01-15', '2016-12-15'

# Select the temperature variable from the product, at this point and these dates
temp_sat = sat['analysed_sst'].sel(lon=lon,lat=lat,method='nearest').sel(time=slice(date_min,date_max))

# Convert Kelvin into Celsius
temp_sat = temp_sat - 273.15

# Display the content of the new variable
temp_sat
# Out:
# <xarray.DataArray 'analysed_sst' (time: 12)>
# array([12.029999, 12.889984, 12.160004, 11.079987, 10.799988,  9.970001,
#         9.389984,  9.279999,  8.970001,  9.290009,  9.799988, 10.570007],
#       dtype=float32)
# Coordinates:
#     lon      float32 280.9
#   * time     (time) datetime64[ns] 2016-01-15T12:00:00 ... 2016-12-15T12:00:00
#     lat      float32 -47.88

# %%
# Define the caracteristics of the plot
f = plt.figure(figsize=(12,8))                                       # create a figure and define its size
ax = f.add_subplot(111)                                              # create the axes of the plot
ax.grid()                                                            # add the grid lines
ax.set_title("Sea Surface Temperature (°C) 2016",fontsize=24)             # add the figure title
f.suptitle('Longitude : ' +str(lon) +'°E\nLatitude : ' + str(lat)+'°N',
           fontsize=18,horizontalalignment='left',x=0.12)            # Display the coordinates on the plot
f.autofmt_xdate()                                                    # format the dates in the x axis 
im = ax.plot(temp_sat['time'],temp_sat)                              # plot the time serie

# Display the location of the point on a mini map
ax_mini_map = f.add_axes([0.73, 0.91, 0.2, 0.15], projection=ccrs.PlateCarree())  # create the minimap and define its projection
gl = ax_mini_map.gridlines(draw_labels=True)                                      # add the coastlines
gl.right_labels = False                                                           # remove latitude labels on the right
gl.top_labels = False                                                             # remove longitude labels on the top
ax_mini_map.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                   # add land mask 
ax_mini_map.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                  # define the extent of the map [lon_min,lon_max,lat_min,lat_max]
ax_mini_map.scatter(lon, lat, 30,transform=ccrs.PlateCarree())                    # plot the location of the point

# Save figure
plt.savefig('images/temp/time_series_sst_penas_2016-2.png')

# %% [markdown]
# ### Coordinate #3

# %%
# Define the coordinates of the point on which to plot the time series
lon, lat = -76, -46
date_min, date_max = '2015-01-15', '2015-12-15'

# Select the temperature variable from the product, at this point and these dates
temp_sat = sat['analysed_sst'].sel(lon=lon,lat=lat,method='nearest').sel(time=slice(date_min,date_max))

# Convert Kelvin into Celsius
temp_sat = temp_sat - 273.15

# Display the content of the new variable
temp_sat
# Out:
# <xarray.DataArray 'analysed_sst' (time: 12)>
# array([12.25    , 13.540009, 13.559998, 12.73999 , 11.700012, 10.320007,
#         9.369995,  8.899994,  8.609985,  8.809998,  9.859985, 11.019989],
#       dtype=float32)
# Coordinates:
#     lon      float32 280.9
#   * time     (time) datetime64[ns] 2015-01-15T12:00:00 ... 2015-12-15T12:00:00
#     lat      float32 -45.88

# %%
# Define the caracteristics of the plot
f = plt.figure(figsize=(12,8))                                       # create a figure and define its size
ax = f.add_subplot(111)                                              # create the axes of the plot
ax.grid()                                                            # add the grid lines
ax.set_title("Sea Surface Temperature (°C) 2015",fontsize=24)             # add the figure title
f.suptitle('Longitude : ' +str(lon) +'°E\nLatitude : ' + str(lat)+'°N',
           fontsize=18,horizontalalignment='left',x=0.12)            # Display the coordinates on the plot
f.autofmt_xdate()                                                    # format the dates in the x axis 
im = ax.plot(temp_sat['time'],temp_sat)                              # plot the time serie

# Display the location of the point on a mini map
ax_mini_map = f.add_axes([0.73, 0.91, 0.2, 0.15], projection=ccrs.PlateCarree())  # create the minimap and define its projection
gl = ax_mini_map.gridlines(draw_labels=True)                                      # add the coastlines
gl.right_labels = False                                                           # remove latitude labels on the right
gl.top_labels = False                                                             # remove longitude labels on the top
ax_mini_map.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                   # add land mask 
ax_mini_map.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                  # define the extent of the map [lon_min,lon_max,lat_min,lat_max]
ax_mini_map.scatter(lon, lat, 30,transform=ccrs.PlateCarree())                    # plot the location of the point

# Save figure
plt.savefig('images/temp/time_series_sst_penas_2015-3.png')

# %%
# Define the coordinates of the point on which to plot the time series
lon, lat = -76, -46
date_min, date_max = '2016-01-15', '2016-12-15'

# Select the temperature variable from the product, at this point and these dates
temp_sat = sat['analysed_sst'].sel(lon=lon,lat=lat,method='nearest').sel(time=slice(date_min,date_max))

# Convert Kelvin into Celsius
temp_sat = temp_sat - 273.15

# Display the content of the new variable
temp_sat
# Out:
# <xarray.DataArray 'analysed_sst' (time: 12)>
# array([12.959991, 13.529999, 13.720001, 12.660004, 12.179993, 11.190002,
#        10.420013,  9.920013,  9.470001,  9.709991, 10.480011, 11.429993],
#       dtype=float32)
# Coordinates:
#     lon      float32 280.9
#   * time     (time) datetime64[ns] 2016-01-15T12:00:00 ... 2016-12-15T12:00:00
#     lat      float32 -45.88

# %%
# Define the caracteristics of the plot
f = plt.figure(figsize=(12,8))                                       # create a figure and define its size
ax = f.add_subplot(111)                                              # create the axes of the plot
ax.grid()                                                            # add the grid lines
ax.set_title("Sea Surface Temperature (°C) 2016",fontsize=24)             # add the figure title
f.suptitle('Longitude : ' +str(lon) +'°E\nLatitude : ' + str(lat)+'°N',
           fontsize=18,horizontalalignment='left',x=0.12)            # Display the coordinates on the plot
f.autofmt_xdate()                                                    # format the dates in the x axis 
im = ax.plot(temp_sat['time'],temp_sat)                              # plot the time serie

# Display the location of the point on a mini map
ax_mini_map = f.add_axes([0.73, 0.91, 0.2, 0.15], projection=ccrs.PlateCarree())  # create the minimap and define its projection
gl = ax_mini_map.gridlines(draw_labels=True)                                      # add the coastlines
gl.right_labels = False                                                           # remove latitude labels on the right
gl.top_labels = False                                                             # remove longitude labels on the top
ax_mini_map.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                   # add land mask 
ax_mini_map.set_extent([-79, -72, -44, -49],crs=ccrs.PlateCarree())                  # define the extent of the map [lon_min,lon_max,lat_min,lat_max]
ax_mini_map.scatter(lon, lat, 30,transform=ccrs.PlateCarree())                    # plot the location of the point

# Save figure
plt.savefig('images/temp/time_series_sst_penas_2016-3.png')
